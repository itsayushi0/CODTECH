# %% [markdown]
# <a href="https://colab.research.google.com/github/itsayushi0/project-task/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📘 README — Weather Data Visualization Using API
#
# *Internship Task - 1*
# *Company:* CodTech IT Solutions
# *Intern Name:* Ayushi Pal
# *Domain:* Python Development / Data Science
# *Task:* API Integration and Data Visualization
#
# ---
#
# ##  Project Description:
# This project demonstrates how to fetch real-time weather data from the OpenWeatherMap API and visualize it using Python libraries like requests, pandas, matplotlib, and seaborn.
#
# ##  Objectives:
# - Learn how to use public APIs
# - Process and visualize live data
# - Display weather stats for multiple cities
#
# ##  Cities Covered:
# - Delhi
# - Mumbai
# - Bangalore
# - Chennai
#
# ##  Visuals:
# - Temperature and Humidity Bar Charts
# - Weather Condition Table

# %%
#(libraries needed)
import requests
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


api_key = "581d0f4be7b78bdfeb7971a5538e058f"  #api generated from Open weather
cities = ["Delhi", "Uttar Pradesh", "Bangalore", "Chennai"]


weather_data = []

for city in cities:
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"
    response = requests.get(url)
    data = response.json()

    if "main" in data and "weather" in data:
        weather_data.append({
            "City": city,
            "Temperature (°C)": data["main"]["temp"],
            "Humidity (%)": data["main"]["humidity"],
            "Condition": data["weather"][0]["main"]
        })
    else:
        print(f"❌ Could not fetch data for {city}. Error: {data}")


df = pd.DataFrame(weather_data)
df
# Out:
#             City  Temperature (°C)  Humidity (%) Condition
# 0          Delhi             33.05            62      Haze
# 1  Uttar Pradesh             29.25            78    Clouds
# 2      Bangalore             26.93            70    Clouds
# 3        Chennai             33.35            76    Clouds
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['Temperature (°C)'].plot(kind='hist', bins=20, title='Temperature (°C)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Humidity (%)'].plot(kind='hist', bins=20, title='Humidity (%)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(8, 5))
sns.barplot(x="City", y="Temperature (°C)", data=df)
plt.title("🌡 City-wise Temperature")
plt.ylabel("Temperature (°C)")
plt.xlabel("City")
plt.show()


plt.figure(figsize=(8, 5))
sns.barplot(x="City", y="Humidity (%)", data=df)
plt.title("💧 City-wise Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("City")
plt.show()


print("🌥 Current Weather Conditions:")
print(df[["City", "Condition"]])
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127777 (\N{THERMOMETER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128167 (\N{DROPLET}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# 🌥 Current Weather Conditions:
#             City Condition
# 0          Delhi      Haze
# 1  Uttar Pradesh    Clouds
# 2      Bangalore    Clouds
# 3        Chennai    Clouds

# %%
df.to_csv("Weather_report.csv",index=False)
